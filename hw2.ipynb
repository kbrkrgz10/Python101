# %%
firstName = input("Please enter your first name: ")
lastName =input("Please enter your last name: ")
age = int(input("Please enter your age: "))
year = input("Please enter your date of birth(year): ")

info = [firstName,lastName,age,year]

for u in info:
  print(u)

if info[2] <= 18:
  print("You can't go out because it's too dangerous")
else:
  print("You can go out to the street")
# Out:
# Please enter your first name: Kübra
# Please enter your last name: Akgözlüoğlu
# Please enter your age: 17
# Please enter your date of birth(year): 2003
# Kübra
# Akgözlüoğlu
# 17
# 2003
# You can't go out because it's too dangerous
